# %%
# print 'CORRECT' if i == 10

value=int(input("Value"))
if(value==10):
    print("Correct")
else:
    print("Incorrect")
# Out:
# Value 10
# Correct

# %%
# Check the password, using if and else
Pass=input("Enter the passowrd:")
if(Pass=="HOPE@123"):
    print("Your password is correct")
else:
    print("Your password is incorrect")
# Out:
# Enter the passowrd: HOPE@123
# Your password is correct

# %%
# category the people by their age like children, audlt, citizen, senior citizen..
input("Enter Name")
Age=int(input("Age:"))
if(Age<18):
    print("Category: Minor")
elif(Age<28):
    print("Category: Adult")
elif(Age<60):
    print("Category: Citizen")
else:
    print("Category: Senior Citizen")
# Out:
# Enter Name Vasanth
# Age: 65
# Category: Senior Citizen

# %%
# Find whether given number is positive or negative
Number=int(input("Enter any number:"))
if(Number>=0):
    print("Number is positive")
else:
    print("Number is negative")
# Out:
# Enter any number: 20
# Number is positive

# %%
# check whether the given number is divisible by 5
Num=int(input("Enter a number to check:"))
if(Num%5==0):
    print("Number is divisible by 5")
else:
    print("Number is not deivisible by 5")
# Out:
# Enter a number to check: 26
# Number is not deivisible by 5
